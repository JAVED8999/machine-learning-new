# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\YA MAALIKUL MULK\Downloads\HP_LinearRegression\honeyproduction.csv")

# %%
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %%
df.describe().transpose()
# Out:
#              count          mean           std        min          25%  \
# numcol       626.0  6.028435e+04  9.107709e+04    2000.00    9000.0000
# yieldpercol  626.0  6.200958e+01  1.945875e+01      19.00      48.0000
# totalprod    626.0  4.169086e+06  6.883847e+06   84000.00  475000.0000
# stocks       626.0  1.318859e+06  2.272964e+06    8000.00  143000.0000
# priceperlb   626.0  1.409569e+00  6.385989e-01       0.49       0.9325
# prodvalue    626.0  4.715741e+06  7.976110e+06  162000.00  759250.0000
# year         626.0  2.004864e+03  4.317306e+00    1998.00    2001.0000
#
#                     50%         75%          max
# numcol         26000.00    63750.00    510000.00
# yieldpercol       60.00       74.00       136.00
# totalprod    1533000.00  4175250.00  46410000.00
# stocks        439500.00  1489500.00  13800000.00
# priceperlb         1.36        1.68         4.15
# prodvalue    1841500.00  4703250.00  69615000.00
# year            2005.00     2009.00      2012.00

# %% [markdown]
# numcol: Number of honey producing colonies. Honey producing colonies are the maximum number of colonies from which honey was taken during the year. It is possible to take honey from colonies which did not survive the entire year
#
# yieldpercol: Honey yield per colony. Unit is pounds
#
# totalprod: Total production (numcol x yieldpercol). Unit is pounds
#
# stocks: Refers to stocks held by producers. Unit is pounds
#
# priceperlb: Refers to average price per pound based on expanded sales. Unit is dollars.

# %%
df_year = df[['numcol','totalprod','year','yieldpercol','stocks','prodvalue']].groupby('year').sum()
df_year
# Out:
#          numcol    totalprod  yieldpercol      stocks    prodvalue
# year
# 1998  2621000.0  219519000.0         3008  80565000.0  146091000.0
# 1999  2637000.0  202387000.0         2815  78390000.0  123657000.0
# 2000  2604000.0  219558000.0         2906  84956000.0  131568000.0
# 2001  2542000.0  185748000.0         2840  64764000.0  132282000.0
# 2002  2565000.0  171265000.0         2939  39177000.0  227302000.0
# 2003  2591000.0  181372000.0         2752  40619000.0  252079000.0
# 2004  2539000.0  182729000.0         2657  60981000.0  197307000.0
# 2005  2394000.0  173969000.0         2635  62187000.0  160793000.0
# 2006  2378000.0  154238000.0         2536  60235000.0  157924000.0
# 2007  2428000.0  147621000.0         2426  52405000.0  161356000.0
# 2008  2326000.0  162972000.0         2501  50996000.0  229992000.0
# 2009  2472000.0  145068000.0         2154  37322000.0  213920000.0
# 2010  2666000.0  175294000.0         2251  44797000.0  278370000.0
# ...

# %%
df_year.reset_index(level=0,inplace=True)
df_year.head()
# Out:
#    year     numcol    totalprod  yieldpercol      stocks    prodvalue
# 0  1998  2621000.0  219519000.0         3008  80565000.0  146091000.0
# 1  1999  2637000.0  202387000.0         2815  78390000.0  123657000.0
# 2  2000  2604000.0  219558000.0         2906  84956000.0  131568000.0
# 3  2001  2542000.0  185748000.0         2840  64764000.0  132282000.0
# 4  2002  2565000.0  171265000.0         2939  39177000.0  227302000.0

# %%
df.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %%
plt.figure(figsize=(25,8))
plt.plot(df_year['year'],df_year['yieldpercol'])
plt.title('trend of honey yield per colony',fontsize=25)
plt.xlabel('year',fontsize=25)
plt.ylabel('yield per colony',fontsize=25)
# Out:
# Text(0, 0.5, 'yield per colony')

# %%
plt.figure(figsize=(25,8))
plt.plot(df_year['year'],df_year['totalprod'])
plt.title('trend of honey yield per colony',fontsize=25)
plt.xlabel('year',fontsize=25)
plt.ylabel('totalprod',fontsize=25)
# Out:
# Text(0, 0.5, 'totalprod')

# %%
us_state=df[['state','totalprod','yieldpercol']].groupby('state').sum()
us_state.reset_index(level=0,inplace=True)
us_state.sort_values(by='totalprod',ascending=False,inplace=True)
us_state.head()
# Out:
#    state    totalprod  yieldpercol
# 23    ND  475085000.0         1321
# 3     CA  347535000.0          837
# 34    SD  266141000.0         1137
# 5     FL  247048000.0         1246
# 21    MT  156562000.0         1160

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,7))
sns.barplot(x=us_state['state'],y=us_state['totalprod'])
plt.title('statewise total honey production in USA',fontsize=20)
plt.xlabel('states',fontsize=20)
plt.ylabel('total honey production in USA',fontsize=20)
# Out:
# Text(0, 0.5, 'total honey production in USA')

# %%
us_state_max= df[['state','totalprod']].groupby('state').max()
us_state_max.reset_index(level=0,inplace=True)
us_state_max.columns=['State','Max Prod']
us_state_max.head()
# Out:
#   State    Max Prod
# 0    AL   1248000.0
# 1    AR   4900000.0
# 2    AZ   3300000.0
# 3    CA  37350000.0
# 4    CO   2700000.0

# %%
plt.figure(figsize=(20,7))
sns.barplot(x=us_state_max['State'],y=us_state_max['Max Prod'])
plt.title('statewise max honey production in USA',fontsize=20)
plt.xlabel('States',fontsize=20)
plt.ylabel('Max honey production in USA',fontsize=20)
# Out:
# Text(0, 0.5, 'Max honey production in USA')

# %%
us_state_min= df[['state','totalprod']].groupby('state').min()
us_state_min.reset_index(level=0,inplace=True)
us_state_min.columns=['State','Min Prod']
us_state_min.head()
# Out:
#   State    Min Prod
# 0    AL    432000.0
# 1    AR   1368000.0
# 2    AZ   1012000.0
# 3    CA  11550000.0
# 4    CO   1200000.0

# %%
plt.figure(figsize=(20,7))
sns.barplot(x=us_state_min['State'],y=us_state_min['Min Prod'])
plt.title('statewise min honey production in USA',fontsize=20)
plt.xlabel('States',fontsize=20)
plt.ylabel('Min honey production in USA',fontsize=20)
# Out:
# Text(0, 0.5, 'Min honey production in USA')

# %%
us_state_mean= df[['state','totalprod']].groupby('state').mean()
us_state_mean.reset_index(level=0,inplace=True)
us_state_mean.columns=['State','Mean Prod']
us_state_mean.head()
# Out:
#   State     Mean Prod
# 0    AL  8.254667e+05
# 1    AR  2.810400e+06
# 2    AZ  2.032267e+06
# 3    CA  2.316900e+07
# 4    CO  1.750600e+06

# %%
plt.figure(figsize=(20,7))
sns.barplot(x=us_state_mean['State'],y=us_state_mean['Mean Prod'])
plt.title('statewise mean honey production in USA',fontsize=20)
plt.xlabel('States',fontsize=20)
plt.ylabel('Mean honey production in USA',fontsize=20)
# Out:
# Text(0, 0.5, 'Mean honey production in USA')

# %%
plt.figure(figsize=(25,8))
plt.plot(df_year['year'],df_year['yieldpercol'])
plt.title('Trend of Honey Yield per Colony' ,fontsize=25)
plt.xlabel('Year',fontsize=25)
plt.ylabel('Yield per Colony',fontsize = 25)
# Out:
# Text(0, 0.5, 'Yield per Colony')

# %%
plt.figure(figsize=(25,8))
plt.plot(df_year['year'],df_year['totalprod'])
plt.title('Total Honey Production in USA' ,fontsize=25)
plt.xlabel('Year',fontsize=25)
plt.ylabel('Total Production of Honey (lbs.)',fontsize = 25)
# Out:
# Text(0, 0.5, 'Total Production of Honey (lbs.)')

# %% [markdown]
# We have seen that total honey production of USA is been on decline

# %%
US_state = df[['state','totalprod','yieldpercol']].groupby('state').sum()
US_state.reset_index(level=0,inplace=True)
US_state.sort_values(by='totalprod',ascending=False,inplace=True)
US_state.head()
# Out:
#    state    totalprod  yieldpercol
# 23    ND  475085000.0         1321
# 3     CA  347535000.0          837
# 34    SD  266141000.0         1137
# 5     FL  247048000.0         1246
# 21    MT  156562000.0         1160

# %%
plt.figure(figsize=(20,7))
sns.barplot(x=US_state['state'],y = US_state['totalprod'])
plt.title('Statewise Total Honey production in USA',fontsize =20)
plt.xlabel('States',fontsize=20)
plt.ylabel('Total Production of Honey in USA',fontsize=20)
# Out:
# Text(0, 0.5, 'Total Production of Honey in USA')

# %%
US_state_max = df[['state','totalprod']].groupby('state').max()
US_state_max.reset_index(level=0,inplace=True)
US_state_max.columns = ['State','Max Prod']
US_state_max.head()
# Out:
#   State    Max Prod
# 0    AL   1248000.0
# 1    AR   4900000.0
# 2    AZ   3300000.0
# 3    CA  37350000.0
# 4    CO   2700000.0

# %%
US_state_min = df[['state','totalprod']].groupby('state').min()
US_state_min.reset_index(level=0,inplace=True)
US_state_min.columns = ['State','Min Prod']
US_state_min.head()
# Out:
#   State    Min Prod
# 0    AL    432000.0
# 1    AR   1368000.0
# 2    AZ   1012000.0
# 3    CA  11550000.0
# 4    CO   1200000.0

# %%
st_range = pd.merge(US_state_max,US_state_min,how='inner',on='State')
st_range.head()
# Out:
#   State    Max Prod    Min Prod
# 0    AL   1248000.0    432000.0
# 1    AR   4900000.0   1368000.0
# 2    AZ   3300000.0   1012000.0
# 3    CA  37350000.0  11550000.0
# 4    CO   2700000.0   1200000.0

# %%
st_range['Per_Change'] = ((st_range['Max Prod']-st_range['Min Prod'])/st_range['Max Prod'])*100
st_range.sort_values(by='Per_Change',ascending=False,inplace=True)
st_range.head()
# Out:
#    State   Max Prod  Min Prod  Per_Change
# 19    MO  1725000.0  344000.0   80.057971
# 26    NM   960000.0  246000.0   74.375000
# 16    ME   451000.0  120000.0   73.392461
# 15    MD   308000.0   84000.0   72.727273
# 12    KS  1120000.0  308000.0   72.500000

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='State',y='Per_Change',data= st_range)
plt.title('Statewise Production Decline Trend',fontsize=20)
plt.xlabel("State",fontsize=15)
plt.ylabel("% Decline",fontsize=15)
# Out:
# Text(0, 0.5, '% Decline')

# %%
honey_corr = df[['numcol','totalprod','year','yieldpercol','stocks','prodvalue']].corr()

honey_corr
# Out:
#                numcol  totalprod      year  yieldpercol    stocks  prodvalue
# numcol       1.000000   0.953594  0.008709     0.243515  0.825929   0.912796
# totalprod    0.953594   1.000000 -0.055556     0.396252  0.878830   0.907236
# year         0.008709  -0.055556  1.000000    -0.232092 -0.119602   0.139451
# yieldpercol  0.243515   0.396252 -0.232092     1.000000  0.367812   0.278977
# stocks       0.825929   0.878830 -0.119602     0.367812  1.000000   0.728560
# prodvalue    0.912796   0.907236  0.139451     0.278977  0.728560   1.000000

# %%
sns.heatmap(honey_corr, annot = True, vmin = -1, vmax = 1, cmap="twilight_shifted")
plt.show()

# %%
sns.lmplot(x = "numcol", y = "prodvalue", data = df, hue = 'year')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['totalprod', 'state'],axis=1), 
                                                    df['totalprod'], test_size=0.20, 
                                                    random_state=8)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
accuracy = model.score(X_test, y_test)
print(accuracy*100,'%')
# Out:
# 95.251143072675 %
